# %%
# Team Project: Part 3
## NFL Player Movement Prediction: Project Part 3

Project Title: project3

Team Name: Group 4

Team member names: Brandon Chung, Hannah Solis, Riley Small, Janet Lu, Rafe Sholler
