# %% [markdown]
# Project Title: project1
# Team Name: group 4
# Team member names: Brandon Chung (906507859), Hannah Solis, Riley Small, Janet Lu, Rafe Sholler
#
# Project Description: https://operations.nfl.com/gameday/analytics/big-data-bowl: The NFL data bowl, a big data competition: potential research question - What is the best regression model to predict first downs
#
# Description of potential source data that would be relevant (including links or references if possible).: data is already uploaded to canvas as well as kaggle.
